# %%
#final inshaallh
from pymongo import MongoClient
import tkinter as tk
from tkinter import messagebox
from pymongo import DESCENDING
import hashlib
import csv
from pymongo import MongoClient
from tkinter import ttk
import subprocess
import tempfile

import tkinter as tk
from tkinter import ttk
class App:
    def __init__(self):
        self.hello = None        
        self.window = None
        self.hello_update= None
        # Connect to MongoDB
        self.client = MongoClient('mongodb://localhost:27017')
        self.db = self.client['breast']
        self.collection =self.db['cancerf'] 
        self.collection2 =self.db['clinical_data'] 

        
        
###########
###########
########### page 1 :

    def open_chcollection(self):
        chcollection = tk.Toplevel()
        chcollection.title("Collection")
        chcollection.geometry("600x400")
        chcollection.configure(bg="gray")
        chcollection.attributes("-fullscreen", True)
        screen_width = chcollection.winfo_screenwidth()
        screen_height = chcollection.winfo_screenheight()
        
        canvas = tk.Canvas(chcollection, width=screen_width, height=screen_height)
        canvas.place(x=0, y=0)

        # Define the pastel gradient colors
        gradient_colors = ["#F8B195", "#F67280", "#C06C84", "#6C5B7B", "#355C7D"]
        for i in range(len(gradient_colors)):
            color = gradient_colors[i]
            x0 = int((i / len(gradient_colors)) * screen_width)
            x1 = int(((i + 1) / len(gradient_colors)) * screen_width)
            canvas.create_rectangle(x0, 0, x1, screen_height, fill=color, width=0)
            
        # choose collection back button
        button3 = tk.Button(chcollection, text="Back", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=chcollection.destroy)
        button3.place(x=1700, y=1000, width=200, height=70)
     
     ####################################################################################################
        
        def open_query_cancer():
            
## => => => => => => => => => => => => => => => @labels & textboxes & buttons@ => => => => => => => => => => => => => => => 

            query_cancer = tk.Toplevel()
            query_cancer.title("Make queries on <Cancer collection>")
            query_cancer.geometry("600x400")
            query_cancer.configure(bg="gray")
            query_cancer.attributes("-fullscreen", True)
            screen_width = query_cancer.winfo_screenwidth()
            screen_height = query_cancer.winfo_screenheight()

            canvas = tk.Canvas(query_cancer, width=screen_width, height=screen_height)
            canvas.place(x=0, y=0)
            

            gradient_colors = ["#F8B195", "#F67280", "#C06C84", "#6C5B7B", "#355C7D"]
            for i in range(len(gradient_colors)):
                color = gradient_colors[i]
                x0 = int((i / len(gradient_colors)) * screen_width)
                x1 = int(((i + 1) / len(gradient_colors)) * screen_width)
                canvas.create_rectangle(x0, 0, x1, screen_height, fill=color, width=0)
            buttonbb = tk.Button(query_cancer, text="Back", font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black", command=query_cancer.destroy)
            buttonbb.place(x=0,y=0, width=100, height=40)
            
            label2 = tk.Label(query_cancer, text="Label 2", anchor="center", cursor="star")
            label2.place(x=100, y=0, width=1900, height=40)
            label2.config(text="Big data cancer file queries", anchor="center", cursor="star", bg="black",
                              font=("Copperplate", 15, "bold"), fg="#F6B195")

            # Entry boxes for inserting data
            
# Entry boxes for inserting data


            ###########################################################################3
            label_id = tk.Label(query_cancer, text="ID:", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black", borderwidth=2, relief="sunken")
            label_id.place(x=50, y=50)

            self.entry_id = tk.Entry(query_cancer)
            self.entry_id.place(x=150, y=60)

            label_symbol = tk.Label(query_cancer, text="Gene Symbol:",width=12, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_symbol.place(x=50, y=90)
            self.entry_symbol = tk.Entry(query_cancer)
            self.entry_symbol.place(x=150, y=100)

            label_name = tk.Label(query_cancer, text="Gene Name:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_name.place(x=50, y=130)
            self.entry_name = tk.Entry(query_cancer)
            self.entry_name.place(x=150, y=140)

            label_s1 = tk.Label(query_cancer, text="Sample 1:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s1.place(x=50, y=170)
            self.entry_s1 = tk.Entry(query_cancer)
            self.entry_s1.place(x=150, y=180)

            label_s2 = tk.Label(query_cancer, text="sample 2:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s2.place(x=50, y=210)
            self.entry_s2 = tk.Entry(query_cancer)
            self.entry_s2.place(x=150, y=220)

            label_s3 = tk.Label(query_cancer, text="Sample 3:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s3.place(x=50, y=250)
            self.entry_s3 = tk.Entry(query_cancer)
            self.entry_s3.place(x=150, y=260)

            label_s4 = tk.Label(query_cancer, text="Sample 4:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s4.place(x=50, y=325)
            self.entry_s4 = tk.Entry(query_cancer)
            self.entry_s4.place(x=150, y=330)

            label_s5 = tk.Label(query_cancer, text="Sample 5: ",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s5.place(x=50, y=365)
            self.entry_s5 = tk.Entry(query_cancer)
            self.entry_s5.place(x=150, y=370)

            label_s6 = tk.Label(query_cancer, text="Sample 6:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s6.place(x=50, y=405)
            self.entry_s6 = tk.Entry(query_cancer)
            self.entry_s6.place(x=150, y=410)

            label_s7 = tk.Label(query_cancer, text="Sample 7:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s7.place(x=50, y=445)
            self.entry_s7 = tk.Entry(query_cancer)
            self.entry_s7.place(x=150, y=450)

            label_s8 = tk.Label(query_cancer, text="Sample 8:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s8.place(x=50, y=485)
            self.entry_s8 = tk.Entry(query_cancer)
            self.entry_s8.place(x=150, y=490)

            label_s9 = tk.Label(query_cancer, text="sample 9:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s9.place(x=50, y=525)
            self.entry_s9 = tk.Entry(query_cancer)
            self.entry_s9.place(x=150, y=530)

            label_s10 = tk.Label(query_cancer, text="Sample 10:",width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_s10.place(x=50, y=565)
            self.entry_s10 = tk.Entry(query_cancer)
            self.entry_s10.place(x=150, y=570)
            

            insert_button = tk.Button(query_cancer, text="Insert", command=self.insert_data, width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            insert_button.place(x=50, y=650)

            update_button = tk.Button(query_cancer, text="Update",command=self.update_document, width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            update_button.place(x=800, y=600)
            
 
            delete_button = tk.Button(query_cancer, text="Delete", command=self.delete_data,width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            delete_button.place(x=800, y=200)
            
            calculate_AVG_button = tk.Button(query_cancer, text=" Calculate Average for \n all sample recoreds", command=self.calculate_avg ,width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            calculate_AVG_button.place(x=400, y=450)
            
            
################ $in operator
            #get gene symbol for all <less>  than 1
            sep_in = tk.Label(query_cancer, text="  Return the 3 accession doument\n usin $in operator :",width=52, height=2, font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black",anchor='w')
            sep_in.place(x=1535, y=40)

            self.accession1_label = tk.Label(query_cancer, text="Accession 1:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.accession1_label.place(x=1540, y=100)           # sep_gt.place(x=1535, y=40)

            self.accession1_entry = tk.Entry(query_cancer)
            self.accession1_entry.place(x=1540, y=130)

            self.accession2_label = tk.Label(query_cancer, text="Accession 2:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.accession2_label.place(x=1540, y=170)

            self.accession2_entry = tk.Entry(query_cancer)
            self.accession2_entry.place(x=1540, y=200)

            self.accession3_label = tk.Label(query_cancer, text="Accession 3:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.accession3_label.place(x=1540, y=240)

            self.accession3_entry = tk.Entry(query_cancer)
            self.accession3_entry.place(x=1540, y=270)

            # Create button to trigger retrieval
            self.retrieve_button = tk.Button(query_cancer, text=" Get three records ", command=self.in_operator, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            self.retrieve_button.place(x=1500, y=320)
############## delete many 


#get gene symbol for all greater than 1
            
            #labels
            sep_gt = tk.Label(query_cancer, text=" Get the symbol geater than 1 :",width=52, height=2, font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black",anchor='w')
            sep_gt.place(x=400, y=40)
        
            db_name_symbol = tk.Label(query_cancer, text="gt_Database Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            db_name_symbol.place(x=400, y=70)

            collection_name_symbol = tk.Label(query_cancer, text="gt_Collection Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            collection_name_symbol.place(x=400, y=90)

            object_name_symbol = tk.Label(query_cancer, text="gt_Object Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            object_name_symbol.place(x=400, y=110)

            #entries 1
            self.db_name = tk.Entry(query_cancer)
            self.db_name.place(x=600, y=70)

            self.collection_name = tk.Entry(query_cancer)
            self.collection_name.place(x=600, y=90)

            self.object_name=tk.Entry(query_cancer)
            self.object_name.place(x=600, y=110)
            
            get_gene_symbols_button = tk.Button(query_cancer, text="Get Gene Symbols <gt>", command=self.get_gene_symbols_with_greater_than_one,width=20, height=2, font=("Copperplate", 20, "bold"), fg="#F6B195", bg="black")
            get_gene_symbols_button.place(x=400, y=150)
##########
# DELETE MANY
            self.field_label = tk.Label(query_cancer, text="Field:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.field_label.place(x=800, y=830)

            # Create a textbox for field input
            self.field_entry = tk.Entry(query_cancer)
            self.field_entry.place(x=800, y=860)

            # Create a label for the value input
            self.value_label = tk.Label(query_cancer, text="Value:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.value_label.place(x=800, y=890)

            # Create a textbox for value input
            self.value_entry = tk.Entry(query_cancer)
            self.value_entry.place(x=800, y=920)
            delete_button = tk.Button(query_cancer, text="Delete Many Documents", command=self.delete_Many_documents, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            delete_button.place(x=800, y=950)
            ###########################################################################
            
            #get gene symbol for all <less>  than 1
            sep_gt = tk.Label(query_cancer, text=" Get the symbol less than 1 :",width=55, height=2, font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black",anchor='w')
            sep_gt.place(x=1150, y=40)

            db_name_label_less = tk.Label(query_cancer, text="Database Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            db_name_label_less.place(x=1150, y=100)
            
            self.db_name_entry_less = tk.Entry(query_cancer)
            self.db_name_entry_less.place(x=1350, y=100)

          
            object_name_label_less = tk.Label(query_cancer, text="Object Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            object_name_label_less.place(x=1150, y=120)
            
            self.object_name_entry_less = tk.Entry(query_cancer)
            self.object_name_entry_less.place(x=1350, y=120)
           
            collection_name_label_less = tk.Label(query_cancer, text="Collection Name:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            collection_name_label_less.place(x=1150, y=140)

            self.collection_name_entry_less = tk.Entry(query_cancer)
            self.collection_name_entry_less.place(x=1350, y=140)
            #entries

                      
            get_gene_name_button_less = tk.Button(query_cancer, text="Get Gene Symbols", command=self.get_gene_symbols_with_less_than_one , width=10, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            get_gene_name_button_less.place(x=1160, y=200,width=350, height=90)
           
            

            ###########################################################################
            # hash labels ,entries
            sep = tk.Label(query_cancer, text="Hashing accession \n number",width=54, height=2,font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black")
            sep.place(x=385, y=350)
            hash_label = tk.Label(query_cancer, text="Enter ID :",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            hash_label.place(x=385, y=400)
            
            self.hash_entry = tk.Entry(query_cancer)
            self.hash_entry.place(x=600, y=410)
            
            # Create a button to perform the hashing and database update
            button = tk.Button(query_cancer, text="Hash", command=self.hash_document_id,width=20, height=2, font=("Copperplate", 20, "bold"), fg="#F6B195", bg="black")
            button.place(x=385, y=450)

           #######################################################################
            #REFRENCE TO CLINICAL DATA STUFFS
            refrence_label = tk.Label(query_cancer, text="Enter RefSeq Accession Number:",width=55, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            refrence_label.place(x=1160, y=400) 

            button_c = tk.Button(query_cancer, text="Retrieve clinical \n data", command=self.retrieve_clinical_data,width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            button_c.place(x=1160, y=500)

            self.refrence_entry = tk.Entry(query_cancer)
            self.refrence_entry.place(x=1160, y=450)

        #####################################################        

            # seperator box for deleting data
            sep_del = tk.Label(query_cancer, text=" Delete the record using ID  :",width=55, height=2, font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black",anchor='w')
            sep_del.place(x=768, y=40)

            label_delete_id = tk.Label(query_cancer, text=" Enter ID to delete:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_delete_id.place(x=800, y=100, width=200)
            
            self.entry_delete_id = tk.Entry(query_cancer)
            self.entry_delete_id.place(x=800, y=150)
            
            #retrieve Button:
            button_retrieve = tk.Button(query_cancer, text="Retrieve DB", command=self.retrieve_data,width=20, height=2, font=("Copperplate", 20, "bold"), fg="red", bg="white")
            button_retrieve.place(x=1600, y=1000)
            
           #count Button:
            db_name_label = tk.Label(query_cancer, text="Database Name:")
            collection_name_label = tk.Label(query_cancer, text="Collection Name:")

            self.db_name_entry = tk.Entry(query_cancer)
            self.collection_name_entry = tk.Entry(query_cancer)

    #get count
            sep_count = tk.Label(query_cancer, text="get the total count of records ",width=54, height=2,font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black")
            sep_count.place(x=0, y=750)

            get_count_button = tk.Button(query_cancer, text="Count records ", command=self.get_document_count,width=15, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            get_count_button.place(x=50, y=800)

            self.count_label = tk.Label(query_cancer, text="",width=26, height=2,font=("Copperplate", 15, "bold"), fg="#355C7D", bg="#F6B195",anchor='w')
            self.count_label.place(x=50, y=890) 
 #---------------#retieve one :---------------------------------
            #Find one doc func
    
            sep_up_re= tk.Label(query_cancer, text=" Retrieve One document: ",width=54, height=2,font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black")
            sep_up_re.place(x=1165, y=610)
    
            button = tk.Button(query_cancer, text="Retrieve", command=self.retrieve_document,width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            button.place(  x=1180, y=820)          
    
            label_one_doc = tk.Label(query_cancer, text=" RefSeq Accession Number:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_one_doc.place(x=1180, y=650)

            self.label_entry_doc = tk.Entry(query_cancer)
            self.label_entry_doc.place(x=1180, y=700)

 #------------ PROJECTION
            self.col1_label = tk.Label(query_cancer, text="Column 1:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.col1_label.place(x=385, y=560)

            self.col1_entry = tk.Entry(query_cancer)
            self.col1_entry.place(x=600, y=560)

            self.col2_label = tk.Label(query_cancer, text="Column 2:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            self.col2_label.place(x=385, y=600)

            self.col2_entry = tk.Entry(query_cancer)
            self.col2_entry.place(x=600, y=600)

            # Create button to trigger projection
            self.projection_button = tk.Button(query_cancer, text="Projection", command=self.projection, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            self.projection_button.place(x=385, y=650)    
#--------------------------------------------------------------------
            # update cancer
         
            self.db_name_entry = tk.Entry(query_cancer)
            collection_name_entry = tk.Entry(query_cancer)
            accession_number_entry = tk.Entry(query_cancer)
            gene_name_entry = tk.Entry(query_cancer)
            
            sep_up = tk.Label(query_cancer, text=" Update gene name: ",width=54, height=2,font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black")
            sep_up.place(x=768, y=350)
            
            label_name = tk.Label(query_cancer, text="DB name", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_name.place(x=800, y=400)
            self.entry_namedb = tk.Entry(query_cancer)
            self.entry_namedb.place(x=1000, y=400)

            label_collection = tk.Label(query_cancer, text="collection_name", width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_collection.place(x=800, y=440)
            self.entry_collection = tk.Entry(query_cancer)
            self.entry_collection.place(x=1000, y=440)

            label_acc = tk.Label(query_cancer, text="accesion number ", width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_acc.place(x=800, y=480)
            self.accession_number_entry = tk.Entry(query_cancer)
            self.accession_number_entry.place(x=1000, y=480)

            label_gene_name = tk.Label(query_cancer, text="gene name", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_gene_name.place(x=800, y=520)
            self.gene_name_entry = tk.Entry(query_cancer)
            self.gene_name_entry.place(x=1000, y=523)

            query_cancer.mainloop()

#$$$end mongo 
            
        #buttons
        button1 = tk.Button(chcollection, text="Make queries on < Cancer data collection >", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=open_query_cancer)
        button1.place(relx=0.5, rely=0.5, anchor="center")

        #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$


        def open_query_clinical():
            query_clinical = tk.Toplevel()
            query_clinical.geometry("600x400")
            query_clinical.configure(bg="gray")
            query_clinical.attributes("-fullscreen", True)
            screen_width = query_clinical.winfo_screenwidth()
            screen_height = query_clinical.winfo_screenheight()

            canvas = tk.Canvas(query_clinical, width=screen_width, height=screen_height)
            canvas.place(x=0, y=0)

            gradient_colors = ["#F8B195", "#F67280", "#C06C84", "#6C5B7B", "#355C7D"]
            for i in range(len(gradient_colors)):
                color = gradient_colors[i]
                x0 = int((i / len(gradient_colors)) * screen_width)
                x1 = int(((i + 1) / len(gradient_colors)) * screen_width)
                canvas.create_rectangle(x0, 0, x1, screen_height, fill=color, width=0)
            #buttonbb = tk.Button(query_clinical, text="Back", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=query_clinical.destroy)
            #buttonbb.place(x=1500, y=900, width=200, height=70)
            
            buttonbb = tk.Button(query_clinical, text="Back", font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black", command=query_clinical.destroy)
            buttonbb.place(x=0,y=0, width=100, height=40)
            
            label2 = tk.Label(query_clinical, text="Label 2", anchor="center", cursor="star")
            label2.place(x=100, y=0, width=1900, height=40)
            label2.config(text="Big data clinical file queries ", anchor="center", cursor="star", bg="black",
                              font=("Copperplate", 15, "bold"), fg="#F6B195")
            
######################################33#Update Many
             # Create a label for the field input
            field_label = tk.Label(query_clinical, text="Field:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            field_label.place(x=1580, y=100)

            # Create a textbox for field input
            self.field_entry = tk.Entry(query_clinical)
            self.field_entry.place(x=1580, y=130)

            # Create a label for the old value input
            old_value_label = tk.Label(query_clinical, text="Old Value:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            old_value_label.place(x=1580, y=160)

            # Create a textbox for old value input
            self.old_value_entry = tk.Entry(query_clinical)
            self.old_value_entry.place(x=1580, y=190)

            # Create a label for the new value input
            new_value_label = tk.Label(query_clinical, text="New Value:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            new_value_label.place(x=1580, y=220)

            # Create a textbox for new value input
            self.new_value_entry = tk.Entry(query_clinical)
            self.new_value_entry.place(x=1580, y=250)

            # Create a button to trigger the update operation
            update_button = tk.Button(query_clinical, text="Update Many Documents", command=self.update_Many_documents, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            update_button.place(x=1580, y=300)
            ##########################################33
            
 #---------------#retieve one :---------------------------------
            #Find one doc func
    
            sep_up_re= tk.Label(query_clinical, text=" Retrieve One document: ",width=54, height=2,font=("Copperplate", 10, "bold"), fg="#F6B195", bg="black")
            sep_up_re.place(x=1600, y=610)
    
            button = tk.Button(query_clinical, text="Retrieve", command=self.retrieve_document_cli,width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            button.place(  x=1600, y=820)          
    
            label_one_doc = tk.Label(query_clinical, text=" RefSeq Accession Number:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_one_doc.place(x=1600, y=650)

            self.label_entry_doc = tk.Entry(query_clinical)
            self.label_entry_doc.place(x=1600, y=780)
################################3

          #---insert  
            label_id = tk.Label(query_clinical, text=" ACC:", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_id.place(x=30, y=60)
            self.entry_accnum = tk.Entry(query_clinical)
            self.entry_accnum.place(x=230, y=60)
        
            label_id = tk.Label(query_clinical, text=" ID:", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_id.place(x=30, y=80)
            self.entry_ID = tk.Entry(query_clinical)
            self.entry_ID.place(x=230, y=90) 
            

            label_symbol = tk.Label(query_clinical, text=" Geneder :",width=14, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_symbol.place(x=30, y=113)
            self.entry_Gender = tk.Entry(query_clinical)
            self.entry_Gender.place(x=230, y=113)

            label_name = tk.Label(query_clinical, text=" ER status :",width=14, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_name.place(x=30, y=140)
            self.entry_ER = tk.Entry(query_clinical)
            self.entry_ER.place(x=230, y=140)

            label_s1 = tk.Label(query_clinical, text=" PR status:",width=14, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s1.place(x=30, y=170)
            self.entry_PR = tk.Entry(query_clinical)
            self.entry_PR.place(x=230, y=170)
            
            label_s2 = tk.Label(query_clinical, text=" Node:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s2.place(x=30, y=210)
            self.entry_Node = tk.Entry(query_clinical)
            self.entry_Node.place(x=230, y=210 )

            label_s2 = tk.Label(query_clinical, text=" Node code:",width=10, height=1, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s2.place(x=30, y=250)
            self.entry_Node_Coded = tk.Entry(query_clinical)
            self.entry_Node_Coded.place(x=230, y=250)

            label_s3 = tk.Label(query_clinical, text=" Metastasis status:",width=20, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s3.place(x=30, y=280)
            self.entry_Metastasis = tk.Entry(query_clinical)
            self.entry_Metastasis.place(x=230, y=280)

            label_s4 = tk.Label(query_clinical, text="Metastasis Code:",width=20, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s4.place(x=30, y=325)
            self.entry_Metastasis_Coded = tk.Entry(query_clinical)
            self.entry_Metastasis_Coded.place(x=230, y=330)

            label_s5 = tk.Label(query_clinical, text=" Survival status: ",width=20, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s5.place(x=30, y=367)
            self.entry_survive = tk.Entry(query_clinical)
            self.entry_survive.place(x=230, y=370)

            label_s6 = tk.Label(query_clinical, text=" PAM50 mRNA score :",width=20, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s6.place(x=30, y=405)
            self.entry_PAM50_mRNA = tk.Entry(query_clinical)
            self.entry_PAM50_mRNA.place(x=230, y=410)

            label_s7 = tk.Label(query_clinical, text=" Methylation cluster score:",width=27, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s7.place(x=30, y=445)
            self.entry_methylation_clust = tk.Entry(query_clinical)
            self.entry_methylation_clust.place(x=230, y=450)

            label_s8 = tk.Label(query_clinical, text=" Gene_exp_cluster:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s8.place(x=30, y=485)
            self.entry_gebe_exp_clust = tk.Entry(query_clinical)
            self.entry_gebe_exp_clust.place(x=230, y=490)

            label_s9 = tk.Label(query_clinical, text="Age at initial diagnosis:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s9.place(x=30, y=525)
            self.entry_Age_InitDiag = tk.Entry(query_clinical)
            self.entry_Age_InitDiag.place(x=230, y=530)
            
            label_s10 = tk.Label(query_clinical, text=" HER2 Final Status:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s10.place(x=30, y=560)
            self.entry_HER2_FinalStatus = tk.Entry(query_clinical)
            self.entry_HER2_FinalStatus.place(x=230, y=570)

            label_s10 = tk.Label(query_clinical, text=" Survival code:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s10.place(x=30, y=593)
            self.entry_survive_code = tk.Entry(query_clinical)
            self.entry_survive_code.place(x=230, y=600)      
            
            label_s10 = tk.Label(query_clinical, text=" OS time:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black",anchor='w')
            label_s10.place(x=30, y=650)
            self.entry_os_time = tk.Entry(query_clinical)
            self.entry_os_time.place(x=230, y=650)
            

            ##################################
#Retrieve 2 col 
             # First column input
            col1_label = tk.Label(query_clinical, text="First Column:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            col1_label.place(x=1180, y=150)
            self.col1_entry = tk.Entry(query_clinical)
            self.col1_entry.place(x=1180, y=200)

            # Second column input
            col2_label = tk.Label(query_clinical, text="Second Column:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            col2_label.place(x=1180, y=250)
            self.col2_entry = tk.Entry(query_clinical)
            self.col2_entry.place(x=1180, y=300)

            # Retrieve Columns button
            button = tk.Button(query_clinical, text=" Retrieve two Columns", command=self.retrieve_columns, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            button.place(x=1180, y=360)
######################################

#cli cli cli 
            # update clinical
         
            self.db_name_entry= tk.Entry(query_clinical)
            collection_name_entry = tk.Entry(query_clinical)
            ID_entry = tk.Entry(query_clinical)
            survive_entry = tk.Entry(query_clinical)
            
            label_name = tk.Label(query_clinical, text=" DB name", width=10, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_name.place(x=800, y=300)
            
            self.db_name_entry = tk.Entry(query_clinical)
            self.db_name_entry.place(x=910, y=300)

            
            label_collection = tk.Label(query_clinical, text=" collection name", width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_collection.place(x=800, y=340)
            
            self.collection_name_entry= tk.Entry(query_clinical)
            self.collection_name_entry.place(x=910, y=340)

            label_acc = tk.Label(query_clinical, text=" Enter ID ", width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_acc.place(x=800, y=380)
            self.ID_entry = tk.Entry(query_clinical)
            self.ID_entry.place(x=910, y=380)

            label_gene_name = tk.Label(query_clinical, text=" Enter patient \nstatus", width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label_gene_name.place(x=800, y=420)
            self.survive_entry = tk.Entry(query_clinical)
            self.survive_entry.place(x=910, y=420)
 #------------ensure INDEXING IN AGE INIT
            # Add a label and entry field for the field name
            label = tk.Label(query_clinical, text=" Enter Field Name:",width=20, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label.place(x=800, y=100)
            self.entry = tk.Entry(query_clinical)
            self.entry.place(x=800, y=120)

            # Add a button for creating the index
            index_button = tk.Button(query_clinical, text="Create Index", command=self.ensure_index, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            index_button.place(x=800, y=180)
            # Add a label for displaying the result
            self.result_label = tk.Label(query_clinical, text="")
            self.result_label.place(x=800, y=160)
                        # Create a button to get the indexes
           
 #--------------buttons on screen : 
            # Create a button to trigger the $sum patients
            calculate_button = tk.Button(query_clinical, text="Calculate Sum of \nDECEASED patients", command=self.calculate_sum,width=15, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            calculate_button.place(x=400,y=930)

            # Create a button to display records as CSV

            insert_button = tk.Button(query_clinical, text="Insert", command=self.insert_data_cli, width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black",anchor='w')
            insert_button.place(x=50, y=710)

            update_button = tk.Button(query_clinical, text="Update",command=self.update_document_cli, width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black",anchor='w')
            update_button.place(x=800, y=500)

           #match males 
            button_find_males = tk.Button(query_clinical, text="Find Males", command=self.find_males, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            button_find_males.place(x=400, y=350)

 #timmmmme           #calculate_AVG_button = tk.Button(query_clinical, text="Calculate Average", command=self.calculate_avg, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w'  )
            #calculate_AVG_button.place(x=400, y=450)
            #retrieve Button:
            button_retrieve = tk.Button(query_clinical, text="Retrieve DB", command=self.retrieve_data_cli,width=20, height=2, font=("Copperplate", 20, "bold"), fg="red", bg="white")
            button_retrieve.place(x=1600, y=1000)
            
            # Create a button to show the min
            
            button = tk.Button(query_clinical, text="Show min age Result", command=self.show_min, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            button.place(x=400, y=150)
            # Create a button to show the min

            button = tk.Button(query_clinical, text="Show max age Results", command=self.show_max, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            button.place(x=400, y=250)
            
            # Create the "min&limit" button

            # Create a button to trigger the search
            search_button = tk.Button(query_clinical, text="Get all ages of patients \n not equal <68> ", command=self.search_records,width=25, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            search_button.place(x=400,y=850)

            # &or doocs
            # Create labels and text boxes for input
            field1_label = tk.Label(query_clinical, text="Field 1:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            field1_label.place(x=800, y=600)
            self.field1_entry = tk.Entry(query_clinical)
            self.field1_entry.place(x=920, y=600)

            value1_label = tk.Label(query_clinical, text="Value 1:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            value1_label.place(x=800, y=640)
            self.value1_entry = tk.Entry(query_clinical)
            self.value1_entry.place(x=920, y=640)

            field2_label = tk.Label(query_clinical, text="Field 2:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            field2_label.place(x=800, y=700)
            self.field2_entry = tk.Entry(query_clinical)
            self.field2_entry.place(x=920, y=700)

            value2_label = tk.Label(query_clinical, text="Value 2:",width=15, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            value2_label.place(x=800, y=740)
            60
            self.value2_entry = tk.Entry(query_clinical)
            self.value2_entry.place(x=920, y=740)

            # Create the retrieve button << Gender >>
            retrieve_button = tk.Button(query_clinical, text="$or", command=self.retrieve_or_documents, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            retrieve_button.place(x=800, y=800)
            # Create the "max &limit" button
            

            button_sort= tk.Button(query_clinical, text="Display Records of \n sorted <dec> age females", command=self.display_records,font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            button_sort.place(x=400, y=45, width=350, height=80)
            
            button_sort= tk.Button(query_clinical, text="Display Records of \n sorted <asc> age females", command=self.display_records_one,font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black")
            button_sort.place(x=400, y=750, width=350, height=80)

            
            #LIMIT ON CLINICAL DATA
            label = tk.Label(query_clinical, text="Enter the number of \n documents to retrieve:",width=25, height=2, font=("Copperplate", 10, "bold"), fg="white", bg="black")
            label.place(x=1180, y=500)

            self.limit_entry = tk.Entry(query_clinical)
            self.limit_entry.place(x=1180, y=550)

            button = tk.Button(query_clinical, text="Retrieve \n Limited Documents", command=self.limit_documents, width=20, height=2, font=("Copperplate", 15, "bold"), fg="#F6B195", bg="black",anchor='w')
            button.place(x=1180, y=570)
          ################################################


            query_clinical.mainloop()

            
        #buttons
        buttonp = tk.Button(chcollection, text="Make queries on <Clinical data collection>", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=open_query_clinical )
        buttonp.place(relx=0.5, rely=0.6, anchor="center")
        

############ page2: start page

    def show_hello(self):
        self.hello.deiconify()  # Show the "Hello" window
        self.chcollection.destroy()  # Destroy the "chcollection" window if it exists
        self.hello_update.deiconify() 

    def startpage(self):
        if self.hello:

            self.hello.deiconify()  # Show the "Big data" window if it exists
        else:
            self.hello = tk.Tk()  # Create the "Big data" window
            self.hello.title("start page")
            self.hello.geometry("200x100")
            # self.hello.resizable(width=False, height=False)
            self.hello.configure(bg="gray")
            # Configure the window to cover the entire screen
            screen_width = self.hello.winfo_screenwidth()
            screen_height = self.hello.winfo_screenheight()
            self.hello.geometry(f"{screen_width}x{screen_height}+0+0")

            # Create a canvas and place it at coordinates (0, 0) to cover the entire window
            canvas = tk.Canvas(self.hello, width=screen_width, height=screen_height)
            canvas.place(x=0, y=0)

            # Define the pastel gradient colors
            gradient_colors = ["#F8B195", "#F67280", "#C06C84", "#6C5B7B", "#355C7D"]

            # Labels:
            label1 = tk.Label(self.hello, text="Label 1", anchor="center", cursor="star", bg="black",
                              font=("Copperplate", 35, "bold"), fg="#F6B195")
            label1.place(x=0, y=20, width=1900, height=300)

            label1.config(text="Welcome to Breast Cancer Proteomes big data \n queries using mongoBD")

            #---screen buttons:
            def show_label1():
                if label2.cget("text") == "":
                    def show_databases(self):
                        # Connect to MongoDB
                        client = MongoClient('mongodb://localhost:27017/')

                        # Get the list of database names
                        database_names = client.list_database_names()

                        # Display the list of databases
                        #messagebox.showinfo("MongoDB Databases", "\n".join(database_names),anchor="center", cursor="star", bg="black", font=("Copperplate", 35, "bold"), fg="#F6B195")
                        label3.config(text="MongoDB Databases:\n" + "\n".join(database_names), anchor="w", cursor="star", bg="black", font=("Copperplate", 35, "bold"), fg="#F6B195")
                        label3.place(x=400, y=600)


                else:
                    label2.config(text="", bg="white")

            def show_label2():
                if label3.cget("text") == "":
                    label3.config(text="You have two Collections:\n 1- Cancer data \n 1- Clinical_data ", anchor="w", cursor="star", bg="black", font=("Copperplate", 35, "bold"), fg="#F6B195")
                    label3.place(x=400, y=600)
                else:
                    label3.config(text="", bg="white")
                    
            button1 = tk.Button(self.hello, text="Show My Databases", command=self.show_databases, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black")
            button1.place(x=0, y=410, width=400, height=100)
            


            button2 = tk.Button(self.hello, text="Show Collections", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=show_label2)
            button2.place(x=0, y=600, width=400, height=100)

            label2 = tk.Label(self.hello, text="", font=("Arial", 12), bg="white")
            label3 = tk.Label(self.hello, text="", font=("Arial", 12), bg="white")
            
            button3 = tk.Button(self.hello, text="Start", font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=self.open_chcollection)
            button3.place(x=0, y=90, width=200, height=70)
           

            outbutton = tk.Button(self.hello, text="Exit", width=10, height=2, font=("Copperplate", 25, "bold"), fg="#F6B195", bg="black", command=self.hello.destroy)
            outbutton.place(x=0, y=200, width=200, height=70)

            # Create a rectangle with a gradient background that covers the entire canvas
            for i in range(len(gradient_colors) - 1):
                y_start = int((i / (len(gradient_colors) - 1)) * screen_height)
                y_end = int(((i + 1) / (len(gradient_colors) - 1)) * screen_height)
                canvas.create_rectangle(0, y_start, screen_width, y_end, fill=gradient_colors[i], width=0)

        self.retrieve_data()  # Call the retrieve_data method to display the data table

        self.hello.mainloop()
#FUNCTION 1  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%INSERT%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def insert_data(self):
        # Check if the ID already exists in the collection
        existing_document = self.collection.find_one({'RefSeq_accession_number': self.entry_id.get()})
        if existing_document:
            # Show a message box indicating that the ID already exists
            messagebox.showinfo('Error', 'ID already exists. Cannot insert the document.')
        else:
            # Create a document to insert
            data = {
                'RefSeq_accession_number': self.entry_id.get(),
                'gene_symbol': self.entry_symbol.get(),
                'gene_name': self.entry_name.get(),
                'AO_A12D': self.entry_s1.get(),
                'C8_A131': self.entry_s2.get(),
                'BH_A18Q': self.entry_s3.get(),
                'C8_A130': self.entry_s4.get(),
                'C8_A138': self.entry_s5.get(),
                'E2_A154': self.entry_s6.get(),
                'C8_A12L': self.entry_s7.get(),
                'A2_A0EX': self.entry_s8.get(),
                'A7_A0CE': self.entry_s9.get(),
                'AN_A04A': self.entry_s10.get(),               

            }

            # Insert the document into the collection
            self.collection.insert_one(data)
            messagebox.showinfo('Success', 'Data inserted successfully.')

#FUNCTION 2  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%DELETE%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def delete_data(self):
        # Check if the ID exists in the collection
        existing_document = self.collection.find_one({'RefSeq_accession_number': self.entry_delete_id.get()})
        if existing_document:
            # Delete the document from the collection
            self.collection.delete_one({'RefSeq_accession_number': self.entry_delete_id.get()})
            messagebox.showinfo('Success', 'Data deleted successfully.')
        else:
            # Show a message box indicating that the ID does not exist
            messagebox.showinfo('Error', 'ID does not exist. Cannot delete the document.')
            
#FUNCTION 3  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%UPDATE%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def update_document(self):
        client = MongoClient()

    # Access the specified database and collection
        db = client['breast']
        collection = db['cancerf']
            # Retrieve data from the collection
        accession_number = self.accession_number_entry.get()
        new_gene_name = self.gene_name_entry.get()
        
            # Update the document object based on the filter and update queries
        filter_query = {'RefSeq_accession_number': accession_number}
        update_query = {'$set': {'gene_name': new_gene_name}}
        collection.update_one(filter_query, update_query)
        messagebox.showinfo('sucess', 'gene name updated .')

#FUNCTION 4  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% AVRAGE %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
                #Aggregate1

    def calculate_avg(self):
    # Define the aggregation pipeline
        pipeline = [
            {
                '$group': {
                    '_id': '$gene_name',
                    'avg': {
                        '$avg': {
                            '$avg': ['$AO_A12D', '$C8_A131', '$BH_A18Q', '$C8_A130', '$C8_A138',
                                     '$E2_A154', '$C8_A12L', '$A2_A0EX', '$A7_A0CE', '$AN_A04A',
                                    ]
                        }
                    }
                }
            }
        ]
         

        # Execute the aggregation pipeline
        result_avg = list(self.collection.aggregate(pipeline))

        # Create a new window to display the result
        result_avg_window = tk.Toplevel(self.hello)
        result_avg_window.title("Aggregation Result")
        #result_avg_window.attributes("-fullscreen", True)

        # Create a Treeview widget to display the result in a table-like structure
        tree = ttk.Treeview(result_avg_window)
        tree["columns"] = ("Gene Name", "Average")
        tree.heading("Gene Name", text="Gene Name")
        tree.heading("Average", text="Average")

        # Create a scrollbar
        scrollbar = ttk.Scrollbar(result_avg_window, orient="vertical", command=tree.yview)
        scrollbar.pack(side="right", fill="y")

        tree.configure(yscrollcommand=scrollbar.set)

        # Insert the aggregation result into the Treeview widget
        for doc in result_avg:
            gene_name = doc['_id']
            avg = doc['avg']
            tree.insert("", "end", values=(gene_name, avg))

        # Pack the Treeview widget
        tree.pack(fill="both", expand=True)
        result_avg_window.mainloop()
#FUNCTION 5 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% get_document_count %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
 
    def get_document_count(self):
        client = MongoClient()
        # Access the specified database
        db = client["breast"]
        # Access the specified collection
        collection = db["cancerf"]

        db_name = self.db_name_entry.get()
        collection_name = self.collection_name_entry.get()

        # Get the count of all documents in the collection
        count = collection.count_documents({})

        # Display the count
        self.count_label.configure(text=f"The number of\n records are: {count}")
        
#FUNCTION ##########refrence to cancer data ########################################################################
    def retrieve_cancer_data(self):
            refseq_acc = self.entry.get()

            # Connect to MongoDB
            client = MongoClient('mongodb://localhost:27017/')
            db = client['breast']  # Replace 'your_database_name' with your actual database name
            clinical_data_collection = db['clinical_data']
            cancer_collection = db['cancerf']

            # Find the document in the 'clinical_data' collection with the specified RefSeq Accession Number
            clinical_data_doc = clinical_data_collection.find_one({"RefSeq_accession_number": refseq_acc})

            if clinical_data_doc:
                # Get the RefSeq Accession Number from the 'clinical_data' collection document
                refseq_acc_clinical = clinical_data_doc['RefSeq_accession_number']

                # Find the document in the 'cancer' collection with the matching RefSeq Accession Number
                cancer_doc = cancer_collection.find_one({"RefSeq_accession_number": refseq_acc_clinical})

            if cancer_doc:
                # Display the document in a message box
                messagebox.showinfo("Document", str(cancer_doc))
            else:
                messagebox.showinfo("Error", "Document not found.")
# FUNCT ######################### IN OPERATOR ##################3
#################################################IN_operatot
    def in_operator(self):
        # Get the user input
        accession1 = self.accession1_entry.get()
        accession2 = self.accession2_entry.get()
        accession3 = self.accession3_entry.get()

        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017/')
        db = client['breast']
        collection = db['cancerf']

        # Prepare the query using the $in operator
        query = {
            "RefSeq_accession_number": {"$in": [accession1, accession2, accession3]}
        }

        # Retrieve documents from the collection with the specified RefSeq_accession_numbers
        documents = collection.find(query)

        # Create a new window to display the result
        result_window = tk.Toplevel()
        result_window.title("Document Data")
        result_window.geometry("600x400")

        # Create a Treeview widget to display the result in a table-like structure
        tree = ttk.Treeview(result_window)
        tree["columns"] = tuple(documents[0].keys()) if documents else ()

        # Format the columns
        for column in tree["columns"]:
            tree.column(column, anchor='center')
            tree.heading(column, text=column)

        # Insert the document data into the Treeview widget
        for doc in documents:
            tree.insert("", "end", values=list(doc.values()))

        # Add scrollbar
        scrollbar = ttk.Scrollbar(result_window, orient="vertical", command=tree.yview)
        scrollbar.pack(side="right", fill="y")

        tree.configure(yscrollcommand=scrollbar.set)

        # Pack the Treeview widget
        tree.pack(fill="both", expand=True)
#FUNCTION  6 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% get gene sym gt 1 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def get_gene_symbols_with_greater_than_one(self):
            # Connect to the MongoDB server
            client = MongoClient()
            db = client['breast']
            collection = db['cancerf']

            # Get the input values from the textboxes
            self.db_name = self.db_name.get()
            collection_name = self.collection_name.get()
            object_name = self.object_name.get()

            # Connect to the MongoDB server
            client = MongoClient()

            # Access the specified database and collection
            db = client['breast']
            collection = db['cancerf']

            # Construct the filter query using the $expr operator
            filter_query = {"$expr": { "$gt": ["$" + object_name, 1]}}

            # Perform the find operation with projection
            results = collection.find(filter_query, {"gene_symbol": 1})

            # Extract the gene symbols from the results
            gene_symbols = [result["gene_symbol"] for result in results]

            # Display the gene symbols in a messagebox
            tk.messagebox.showinfo("Gene Symbols", f"The gene symbols are: {gene_symbols}")


#FUNCTION  8 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% gene name lt 1 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  
    def get_gene_symbols_with_less_than_one(self):
                # Connect to the MongoDB server
            client = MongoClient()
            db = client['breast']
            collection = db['cancerf']

            # Get the input values from the textboxes
            self.db_name_less = self.db_name_entry_less.get()
            collection_name_less = self.collection_name_entry_less.get()
            object_name_less = self.object_name_entry_less.get()

            client = MongoClient()

            # Access the specified database and collection
            db = client['breast']
            collection = db['cancerf']

            # Construct the filter query using the $expr operator
            filter_querys = {"$expr": {"$lt": ["$" + object_name_less, 1]}}

            # Perform the find operation with projection
            resultss = collection.find(filter_querys, {"gene_symbol": 1})

            # Extract the gene symbols from the results
            gene_symbolss = [result["gene_symbol"] for result in resultss]

            

            # Display the gene symbols in a messagebox
            tk.messagebox.showinfo("Gene Symbols", f"The gene symbols are: {gene_symbolss}")
#FUNCTION  7 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% HASH %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def hash_document_id(self):
        # Get the document ID from the entry field
        document_id = self.hash_entry.get()

        # Hash the document ID using SHA-256
        hashed_id = hashlib.sha256(document_id.encode()).hexdigest()

        # Connect to the MongoDB database
        client = MongoClient('mongodb://localhost:27017')
        db = client['breast']
        collection = db['cancerf']

        # Update the document with the hashed ID
        collection.update_one({'RefSeq_accession_number': document_id}, {'$set': {'RefSeq_accession_number': '#' * len(hashed_id)}})
        messagebox.showinfo("success","ID Hashed Successfully !")
 #####################Projection
    def projection(self):
        # Get the user input
        col1 = self.col1_entry.get()
        col2 = self.col2_entry.get()

        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017/')
        db = client['breast']
        collection = db['cancerf']

        # Prepare the projection fields
        projection = {
            col1: 1,
            col2: 1,
            '_id': 0
        }

        # Retrieve documents from the collection with projection
        documents = collection.find({}, projection)

        # Create a new window to display the result
        result_window = tk.Toplevel()
        result_window.title("Column Data")
        result_window.geometry("600x400")

        # Create a Treeview widget to display the result in a table-like structure
        tree = ttk.Treeview(result_window)
        tree["columns"] = (col1, col2)
        tree.heading(col1, text=col1)
        tree.heading(col2, text=col2)

        # Create a scrollbar
        scrollbar = ttk.Scrollbar(result_window, orient="vertical", command=tree.yview)
        scrollbar.pack(side="right", fill="y")

        tree.configure(yscrollcommand=scrollbar.set)

        # Insert the column values into the Treeview widget
        for document in documents:
            values = [document.get(col1, ""), document.get(col2, "")]
            tree.insert("", "end", values=values)

        # Pack the Treeview widget
        tree.pack(fill="both", expand=True)       
#FUNCTION ############################# retrive one################################
    def retrieve_document(self):
            accession_number = self.label_entry_doc.get()

            # Perform the query
            document = self.collection.find_one({'RefSeq_accession_number': accession_number})

            if document:
                # Display the document in a message box
                messagebox.showinfo("Document", str(document))
            else:
                messagebox.showinfo("Error", "Document not found.")
                
                
#FUNCTION 2  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%DELETEMANY%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def delete_Many_documents(self):
        field = self.field_entry.get()
        value = self.value_entry.get()
        
        # Check if any documents exist with the given field value
        existing_documents = self.collection.count_documents({field: value})
    
        if existing_documents > 0:
            # Delete all documents with the given field value
            self.collection.delete_many({field: value})
            messagebox.showinfo('Success', 'Documents deleted successfully.')
        else:
            # Show a message box indicating that no documents were found
            messagebox.showinfo('Error', 'No documents found with the specified field value.')                
#FUNCTION   %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% retrieve %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def retrieve_data(self):
        # Retrieve data from the collection
        data = self.collection.find().sort('_id', DESCENDING)

        # Create a new window for the results
        results_window = tk.Toplevel(self.hello)
        results_window.title("Results")
        results_window.geometry("800x600")

        # Create a frame to hold the table and scrollbars
        frame = tk.Frame(results_window)
        frame.pack(fill='both', expand=True)

        # Create a vertical scrollbar
        y_scrollbar = ttk.Scrollbar(frame, orient='vertical')
        y_scrollbar.pack(side='right', fill='y')

        # Create a horizontal scrollbar
        x_scrollbar = ttk.Scrollbar(frame, orient='horizontal')
        x_scrollbar.pack(side='bottom', fill='x')

        # Create a treeview widget to display the data
        treeview = ttk.Treeview(frame, yscrollcommand=y_scrollbar.set, xscrollcommand=x_scrollbar.set)
        treeview.pack(fill='both', expand=True)

        # Configure the scrollbars
        y_scrollbar.configure(command=treeview.yview)
        x_scrollbar.configure(command=treeview.xview)

        # Define the columns
        columns = tuple(data[0].keys())
        treeview['columns'] = columns

        # Configure the columns
        for column in columns:
            treeview.column(column, anchor='center', width=100)
            treeview.heading(column, text=column)

        # Add a border style to the treeview
        style = ttk.Style()
        style.configure("Treeview", borderwidth=1, relief="solid")

        # Insert the data into the treeview
        for document in data:
            treeview.insert('', 'end', values=tuple(document.values()))

        results_window.mainloop()
        
#---cli- FUNCTION  1 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% insert %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def insert_data_cli(self):
        # Check if the ID already exists in the collection
        existing_document = self.collection2.find_one({'RefSeq_accession_number': self.entry_accnum.get()})
        if existing_document:
            # Show a message box indicating that the ID already exists
            messagebox.showinfo('Error', 'ACC already exists. Cannot insert the document.')
        else:
            # Create a document to insert
            data = {

                'RefSeq_accession_number': self.entry_accnum.get(), #\\\\\\
                'ID': self.entry_ID.get(),
                'Gender': self.entry_Gender.get(),
                'ER': self.entry_ER.get(),
                'PR': self.entry_PR.get(),
                'Node': self.entry_Node.get(),
                'Node_Coded': self.entry_Node_Coded.get(),
                'Metastasis': self.entry_Metastasis.get(),
                'Metastasis_Coded': self.entry_Metastasis_Coded.get(),
                'survive': self.entry_survive.get(),
                'PAM50_mRNA': self.entry_PAM50_mRNA.get(),
                'methylation_clust': self.entry_methylation_clust.get(),
                'gebe_exp_clust': self.entry_gebe_exp_clust.get(),
                'Age_InitDiag': self.entry_Age_InitDiag.get(),               
                'HER2_FinalStatus': self.entry_HER2_FinalStatus.get(),
                'survive_code': self.entry_survive_code.get(),
                'OS_Time': self.entry_os_time.get(),             

            }

            self.collection2.insert_one(data)
            messagebox.showinfo('Success', 'Data inserted successfully.')
            
            
    #---cli- FUNCTION  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% ماتش %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def find_males(self):
        # Connect to MongoDB
        client = MongoClient()

        db = client['breast']
        collection2 = db['clinical_data']

        # Perform aggregation match query for males
        pipeline = [
            {"$match": {"Gender": "MALE"}}
        ]
        result = collection2.aggregate(pipeline)

        # Create a new Tkinter window
        result_window = tk.Toplevel()

        # Iterate over the result and display the matched records in the window
        for record in result:
            for key, value in record.items():
                label = tk.Label(result_window, text=f"{key}: {value}")
                label.pack()
###############INDEXING
    def ensure_index(self):
    # Get the field name from the entry field
        field_name = self.entry.get()

        # Connect to the MongoDB database
        client = MongoClient('mongodb://localhost:27017')
        db = client['breast']
        collection = db['clinical_data']

        # Create an index on the specified field
        collection.create_index([(field_name, 1)])

        # Check if the index exists
        index_info = collection.index_information()
        if field_name + "_1" in index_info:
            self.result_label.config(text="Index added to {} field.".format(field_name))
        else:
            self.result_label.config(text="Error: Failed to add index to {} field.".format(field_name))

#---cli- FUNCTION  2 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% sort female age %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    import tkinter as tk
    import csv
    import tempfile
    from pymongo import MongoClient
    from tkinter import ttk
    import subprocess

    # Rest of the code remains the same...


    def display_records(self):
        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017')
        db = client['breast']
        collection2 = db['clinical_data']

        # Perform aggregate pipeline to match females and sort by Age_InitDiag
        pipeline = [
            {"$match": {"Gender": "FEMALE"}},
            {"$sort": {"Age_InitDiag": -1}}
        ]
        result = collection2.aggregate(pipeline)

        # Create a temporary file to save the CSV data
        temp_file_path = tempfile.NamedTemporaryFile(mode='w', delete=False, suffix='.csv').name

        # Save the records as a CSV file
        with open(temp_file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            headers = ["RefSeq_accession_number", "ID", "Gender", "ER", "PR", "Node", "Node_Coded",
                       "Metastasis", "Metastasis_Coded", "survive", "PAM50_mRNA", "methylation_clust",
                       "gebe_exp_clust", "Age_InitDiag", "HER2_FinalStatus", "survive_code", "OS_Time"]
            writer.writerow(headers)
            for record in result:
                writer.writerow([record.get(key, "") for key in headers])

        # Open the CSV file using the default system application
        subprocess.run(['xdg-open', temp_file_path])
        
#------------
#----cli----------######################### retrive one################################

    def retrieve_document_cli(self):
        
            accession_number = self.label_entry_doc.get()

            # Perform the query
            document = self.collection2.find_one({'RefSeq_accession_number': accession_number})

            if document:
                # Display the document in a message box
                messagebox.showinfo("Document", str(document))
            else:
                messagebox.showinfo("Error", "Document not found.")
                


#----cli-----------%%%%%%%%%%%%%%%%%%%%%%% not equal age=68 %%%%%%%%%%%%%%%%%5
    def search_records(self):
        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017/')
        db = client['breast']
        collection2 = db['clinical_data']

        # Perform the MongoDB query
        query = {"Age_InitDiag": {"$ne": 68}}
        results = list(collection2.find(query))

        # Create a new window
        window = tk.Toplevel()
        window.title("Search Results")

        # Get the screen width and height
        screen_width = window.winfo_screenwidth()
        screen_height = window.winfo_screenheight()

        # Create a table frame to hold the table and scrollbar
        table_frame = ttk.Frame(window)
        table_frame.pack(fill="both", expand=True)

        # Create a table to display the results
        table = ttk.Treeview(table_frame)
        table["columns"] = list(results[0].keys())

        # Format the table columns
        for column in table["columns"]:
            table.column(column, width=100)
            table.heading(column, text=column)

        # Insert the data into the table
        for row in results:
            table.insert("", "end", values=list(row.values()))

        # Add a vertical scrollbar to the table
        scrollbar_y = ttk.Scrollbar(table_frame, orient="vertical", command=table.yview)
        table.configure(yscroll=scrollbar_y.set)
        scrollbar_y.pack(side="right", fill="y")

        # Add a horizontal scrollbar to the table
        scrollbar_x = ttk.Scrollbar(window, orient="horizontal", command=table.xview)
        table.configure(xscroll=scrollbar_x.set)
        scrollbar_x.pack(side="bottom", fill="x")

        # Pack the table
        table.pack(fill="both", expand=True)

        # Set the window size to occupy the full screen
        window.geometry(f"{screen_width}x{screen_height}")
#---cil function ################### sort <1> ascending ##########################################################3

    def display_records_one(self):
        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017')
        db = client['breast']
        collection2 = db['clinical_data']

        # Perform aggregate pipeline to match females and sort by Age_InitDiag
        pipeline = [
            {"$match": {"Gender": "FEMALE"}},
            {"$sort": {"Age_InitDiag": 1}}
        ]
        result = collection2.aggregate(pipeline)

        # Create a temporary file to save the CSV data
        temp_file_path = tempfile.NamedTemporaryFile(mode='w', delete=False, suffix='.csv').name

        # Save the records as a CSV file
        with open(temp_file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            headers = ["RefSeq_accession_number", "ID", "Gender", "ER", "PR", "Node", "Node_Coded",
                       "Metastasis", "Metastasis_Coded", "survive", "PAM50_mRNA", "methylation_clust",
                       "gebe_exp_clust", "Age_InitDiag", "HER2_FinalStatus", "survive_code", "OS_Time"]
            writer.writerow(headers)
            for record in result:
                writer.writerow([record.get(key, "") for key in headers])

        # Open the CSV file using the default system application
        subprocess.run(['xdg-open', temp_file_path])

#---cil function ################### OR ##########################################################3
    def retrieve_or_documents(self):
        field1 = self.field1_entry.get()
        value1 = self.value1_entry.get()
        field2 = self.field2_entry.get()
        value2 = self.value2_entry.get()

        # Connect to the MongoDB server
        client = MongoClient('localhost', 27017)

        # Access the database and collection
        db = client['breast']
        collection = db['clinical_data']

        # Prepare the queries
        query1 = { field1: value1 }
        query2 = { field2: value2 }
        query = { '$or': [query1, query2] }

        # Retrieve the documents matching the query
        documents = list(collection.find(query))

        # Create the GUI window
        window = tk.Tk()
        window.title('Clinical Data Results')

        # Create the treeview widget
        tree = ttk.Treeview(window)

        # Define the columns
        tree['columns'] = tuple(documents[0].keys()) if documents else ()

        # Format the columns
        for column in tree['columns']:
            tree.column(column, anchor='center')
            tree.heading(column, text=column)

        # Insert the document data into the treeview
        for doc in documents:
            tree.insert('', 'end', values=list(doc.values()))

        # Add scrollbar
        scrollbar = ttk.Scrollbar(window, orient="vertical", command=tree.yview)
        tree.configure(yscroll=scrollbar.set)
        scrollbar.pack(side="right", fill="y")

        # Pack the treeview
        tree.pack(expand=True, fill='both')
#--cli_ function ################### update_document_clinical#############################33
    def update_document_cli(self):
        client = MongoClient()

    # Access the specified database and collection
        db = client['breast']
        collection2 = db['clinical_data']
        
            # Retrieve data from the collection
        accession_number = self.ID_entry.get()
        new_survive = self.survive_entry.get()
        
            # Update the document object based on the filter and update queries
            
        filter_query = {'RefSeq_accession_number': accession_number} #//// sure id_entry
        update_query = {'$set': {'survive': new_survive}}
        collection2.update_one(filter_query, update_query)
        messagebox.showinfo('success', 'update success !')
#---cli- FUNCTION  2 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% group --min %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def show_min(self):
        client = MongoClient()

    # Access the specified database and collection
        db = client['breast']
        collection2 = db['clinical_data']
        result_window = tk.Tk()
        result_window.title("Result")



        # Perform the aggregation query
        result = collection2.aggregate([{"$group": {"_id": "$Gender", "Min": {"$min": "$Age_InitDiag"}}}])

        # Create a new window to display the result

        # Create a label to show the result
        result_label = tk.Label(result_window, text="", width=30)
        result_label.pack(padx=10, pady=10)

        # Format the result and display it in the label
        text = ""
        for doc in result:
            text += f"{doc['_id']}: {doc['Min']}\n"
        result_label.config(text=text if text else "No data available")
#---cli- FUNCTION   %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% group --max %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def show_max(self):
        client = MongoClient()

    # Access the specified database and collection
        db = client['breast']
        collection2 = db['clinical_data']
        result_window = tk.Tk()
        result_window.title("Result")



        # Perform the aggregation query
        result = collection2.aggregate([
            {"$group": {"_id": "$Gender", "Max": {"$max": "$Age_InitDiag"}}}
        ])

        # Create a new window to display the result

        # Create a label to show the result
        result_label = tk.Label(result_window, text="", width=30)
        result_label.pack(padx=10, pady=10)

        # Format the result and display it in the label
        text = ""
        for doc in result:
            text += f"{doc['_id']}: {doc['Max']}\n"
        result_label.config(text=text if text else "No data available")

#----cli function ############################refrence to clinical data ############################
    def retrieve_clinical_data(self):
            refseq_acc = self.refrence_entry.get()

            # Connect to MongoDB
            client = MongoClient('mongodb://localhost:27017/')
            db = client['breast']  # Replace 'your_database_name' with your actual database name
            cancer_collection = db['cancerf']
            clinical_data_collection = db['clinical_data']

            # Find the document in the 'cancer' collection with the specified RefSeq Accession Number
            cancer_doc = cancer_collection.find_one({"RefSeq_accession_number": refseq_acc})

            if cancer_doc:
                # Get the RefSeq Accession Number from the 'cancer' collection document
                refseq_acc_cancer = cancer_doc['RefSeq_accession_number']

                # Find the document in the 'clinical_data' collection with the matching RefSeq Accession Number
                clinical_data_doc = clinical_data_collection.find_one({"RefSeq_accession_number": refseq_acc_cancer})

            if clinical_data_doc:
                # Display the document in a message box
                messagebox.showinfo("Document", str(clinical_data_doc))
            else:
                messagebox.showinfo("Error", "Document not found.")

        #---show all databases %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%5
    def show_databases(self):
        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017/')

        # Get the list of database names
        database_names = client.list_database_names()

        # Display the list of databases
        messagebox.showinfo("MongoDB Databases", "\n".join(database_names))

####################################################  $and###############
    def retrieve_documents(self):
        field1 = self.field1_entry.get()
        value1 = self.value1_entry.get()
        field2 = self.field2_entry.get()
        value2 = self.value2_entry.get()

        # Connect to the MongoDB server
        client = MongoClient('localhost', 27017)

        # Access the database and collection
        db = client['breast']
        collection = db['clinical_data']

        # Prepare the $and query
        query = {
            '$and': [
                {field1: value1},
                {field2: value2}
            ]
        }

        # Retrieve the documents matching the query
        documents = list(collection.find(query))

        # Create the GUI window
        window = tk.Tk()
        window.title('Clinical Data Results')

        # Create the treeview widget
        tree = ttk.Treeview(window)

        # Define the columns
        tree['columns'] = tuple(documents[0].keys()) if documents else ()

        # Format the columns
        for column in tree['columns']:
            tree.column(column, anchor='center')
            tree.heading(column, text=column)

        # Insert the document data into the treeview
        for doc in documents:
            tree.insert('', 'end', values=list(doc.values()))

        # Add scrollbar
        scrollbar = ttk.Scrollbar(window, orient="vertical", command=tree.yview)
        tree.configure(yscroll=scrollbar.set)
        scrollbar.pack(side="right", fill="y")

        # Pack the treeview
        tree.pack(expand=True, fill='both')
    
    #---cli_ function ################################## limit###########################################################


    def limit_documents(self):
            # Get the number of documents to retrieve from the user
            limit = int(self.limit_entry.get())

          # Connect to MongoDB
            client = MongoClient('mongodb://localhost:27017/')
            db = client['breast']  # Replace 'your_database_name' with your actual database name
            collection = db['clinical_data']

            # Retrieve the documents based on the specified limit
            documents = collection.find().limit(limit)
         # Create a new window to display the result
            result_window = tk.Toplevel()
            result_window.title("Documents")
            result_window.geometry("800x400")

            # Create a Treeview widget to display the result in a table-like structure
            tree = ttk.Treeview(result_window)
            tree["columns"] = ("RefSeq Accession Number", "ID", "Gender", "ER", "PR", "Node", "Node_Coded", "Metastasis", "Metastasis_Coded", "Survive", "PAM50 mRNA", "Methylation Clust", "GEBE Exp Clust", "Age InitDiag", "HER2 FinalStatus", "Survive Code", "OS Time")
            tree.heading("RefSeq Accession Number", text="RefSeq Accession Number")
            tree.heading("ID", text="ID")
            tree.heading("Gender", text="Gender")
            tree.heading("ER", text="ER")
            tree.heading("PR", text="PR")
            tree.heading("Node", text="Node")
            tree.heading("Node_Coded", text="Node Coded")
            tree.heading("Metastasis", text="Metastasis")
            tree.heading("Metastasis_Coded", text="Metastasis Coded")
            tree.heading("Survive", text="Survive")
            tree.heading("PAM50 mRNA", text="PAM50 mRNA")
            tree.heading("Methylation Clust", text="Methylation Clust")
            tree.heading("GEBE Exp Clust", text="GEBE Exp Clust")
            tree.heading("Age InitDiag", text="Age InitDiag")
            tree.heading("HER2 FinalStatus", text="HER2 FinalStatus")
            tree.heading("Survive Code", text="Survive Code")
            tree.heading("OS Time", text="OS Time")

            # Create a scrollbar
            scrollbar = ttk.Scrollbar(result_window, orient="vertical", command=tree.yview)
            scrollbar.pack(side="right", fill="y")

            tree.configure(yscrollcommand=scrollbar.set)

            # Insert the documents into the Treeview widget
            for document in documents:
                refseq = document['RefSeq_accession_number']
                id_val = document['ID']
                gender = document['Gender']
                er = document['ER']
                pr = document['PR']
                node = document['Node']
                node_coded = document['Node_Coded']
                metastasis = document['Metastasis']
                metastasis_coded = document['Metastasis_Coded']
                survive = document['survive']
                pam50_mrna = document['PAM50_mRNA']
                methylation_clust = document['methylation_clust']
                gebe_exp_clust = document['gebe_exp_clust']
                age_initdiag = document['Age_InitDiag']
                her2_finalstatus = document['HER2_FinalStatus']
                survive_code = document['survive_code']
                os_time = document['OS_Time']

                tree.insert("", "end", values=(refseq, id_val, gender, er, pr, node, node_coded, metastasis, metastasis_coded, survive, pam50_mrna, methylation_clust, gebe_exp_clust, age_initdiag, her2_finalstatus, survive_code, os_time))

            # Pack the Treeview widget
            tree.pack(fill="both", expand=True)
#---cli- FUNCTION  2 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% retrieve 2 col %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def retrieve_columns(self):
            # Get the user input
            col1 = self.col1_entry.get()
            col2 = self.col2_entry.get()

            # Connect to MongoDB
            client = MongoClient('mongodb://localhost:27017/')
            db = client['breast']
            collection = db['clinical_data']

            # Retrieve all documents from the collection
            documents = collection.find()

            # Create a new window to display the result
            result_window = tk.Toplevel()
            result_window.title("Column Data")
            result_window.geometry("600x400")

            # Create a Treeview widget to display the result in a table-like structure
            tree = ttk.Treeview(result_window)
            tree["columns"] = (col1, col2)
            tree.heading(col1, text=col1)
            tree.heading(col2, text=col2)

            # Create a scrollbar
            scrollbar = ttk.Scrollbar(result_window, orient="vertical", command=tree.yview)
            scrollbar.pack(side="right", fill="y")

            tree.configure(yscrollcommand=scrollbar.set)

            # Insert the column values into the Treeview widget
            for document in documents:
                value1 = document.get(col1, "")
                value2 = document.get(col2, "")
                tree.insert("", "end", values=(value1, value2))

            # Pack the Treeview widget
            tree.pack(fill="both", expand=True)

            
#---cli- FUNCTION   %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% limit3 min %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
            
            
    def limit_min(self):
        # Connect to the MongoDB server
        client = MongoClient('mongodb://localhost:27017')
        # Access the desired database and collection
        db = client['breast']
        collection2 = db['clinical_data']

        # Execute the aggregation pipeline
        pipeline = [
            {"$group": {"_id": "$Gender", "Min": {"$min": "$Age_InitDiag"}}},
            {"$limit": 3}
        ]
        result = list(collection2.aggregate(pipeline))

        # Create a new window for displaying the result
        result_window = tk.Toplevel()

        # Create a CSV file to store the result
        with open('result.csv', 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=['Gender', 'Min'])
            writer.writeheader()

            # Write the result to the CSV file and display it in the window
            for record in result:
                writer.writerow({'Gender': record['_id'], 'Min': record['Min']})
                tk.Label(result_window, text=f"Gender: {record['_id']}, Min: {record['Min']}").pack()

#---cli func %%%%%%%%%%%%%%%%%%%%%%%%%%%%% $ sum operator in survive_code to count dead $$$$$$$$$$$$$$$$$4

    def calculate_sum(self):
        # Connect to MongoDB
        client = MongoClient('mongodb://localhost:27017/')
        db = client['breast']
        collection2 = db['clinical_data']

        # Perform the MongoDB aggregation
        pipeline = [
            {
                "$match": {
                    "survive": "DECEASED"
                }
            },
            {
                "$group": {
                    "_id": "RefSeq_accession_number",
                    "sum": {"$sum": "$survive_code"}
                }
            }
        ]
        result = list(collection2.aggregate(pipeline))

        # Extract the sum from the aggregation result
        sum_value = result[0]["sum"]

        # Display the message box
        messagebox.showinfo("Sum of DECEASED Patients", f"The sum of all DECEASED patients is: {sum_value}")

#---cli Function %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%max limit 5 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

    def limit_max(self):
        # Connect to the MongoDB server
        client = MongoClient('mongodb://localhost:27017')
        # Access the desired database and collection
        db = client['breast']
        collection2 = db['clinical_data']

        # Execute the aggregation pipeline
        pipeline = [
            {"$group": {"_id": "$Gender", "Max": {"$max": "$Age_InitDiag"}}},
            {"$limit": 5}
        ]
        result = list(collection2.aggregate(pipeline))

        # Create a new window for displaying the result
        result_window = tk.Toplevel()

        # Create a CSV file to store the result
        with open('result.csv', 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=['Gender', 'Min'])
            writer.writeheader()

            # Write the result to the CSV file and display it in the window
            for record in result:
                writer.writerow({'Gender': record['_id'], 'Min': record['Min']})
                tk.Label(result_window, text=f"Gender: {record['_id']}, Min: {record['Min']}").pack()

#---cli- FUNCTION  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  update_Many_documents ################################33
    def update_Many_documents(self):
          # Connect to your MongoDB database and collection
            self.client = MongoClient('mongodb://localhost:27017/')
            self.db = self.client['breast']
            self.collection = self.db['clinical_data']

            field = self.field_entry.get()
            old_value = self.old_value_entry.get()
            new_value = self.new_value_entry.get()

            # Update all documents with the given field value
            result = self.collection.update_many({field: old_value}, {"$set": {field: new_value}})

            if result.modified_count > 0:
                messagebox.showinfo('Success', 'Documents updated successfully.')
            else:
                messagebox.showinfo('Error', 'No documents found with the specified field value or no updates were made.')
#######3

    def get_indexes():
        # Connect to the MongoDB database
        client = MongoClient('mongodb://localhost:27017')
        db = client['breast']
        collection = db['clinical_data']

        # Get the indexes of the collection
        indexes = collection.index_information()

        # Clear existing data in the labels
        index_info_label.config(text="")

        # Insert index data into the label
        for index_name, index_info in indexes.items():
            index_info_label.config(text=index_info_label.cget("text") + f"{index_name}: {index_info}\n")


#---cli- FUNCTION  2 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%% retrieve %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    def retrieve_data_cli(self):
        # Retrieve data from the collection
        data = self.collection2.find().sort('_id', DESCENDING)

        # Create a new window for the results
        results_window_cli = tk.Toplevel(self.hello)
        results_window_cli.title("Results")
        results_window_cli.geometry("800x600")

        # Create a frame to hold the table and scrollbars
        frame = tk.Frame(results_window_cli)
        frame.pack(fill='both', expand=True)

        # Create a vertical scrollbar
        y_scrollbar = ttk.Scrollbar(frame, orient='vertical')
        y_scrollbar.pack(side='right', fill='y')

        # Create a horizontal scrollbar
        x_scrollbar = ttk.Scrollbar(frame, orient='horizontal')
        x_scrollbar.pack(side='bottom', fill='x')

        # Create a treeview widget to display the data
        treeview = ttk.Treeview(frame, yscrollcommand=y_scrollbar.set, xscrollcommand=x_scrollbar.set)
        treeview.pack(fill='both', expand=True)

        # Configure the scrollbars
        y_scrollbar.configure(command=treeview.yview)
        x_scrollbar.configure(command=treeview.xview)

        # Define the columns
        columns = tuple(data[0].keys())
        treeview['columns'] = columns

        # Configure the columns
        for column in columns:
            treeview.column(column, anchor='center', width=100)
            treeview.heading(column, text=column)

        # Add a border style to the treeview
        style = ttk.Style()
        style.configure("Treeview", borderwidth=1, relief="solid")

        # Insert the data into the treeview
        for document in data:
            treeview.insert('', 'end', values=tuple(document.values()))

        results_window_cli.mainloop()


    
if __name__ == "__main__":
    app = App()
    app.startpage()
    #################################

# %%
import tkinter as tk
from tkinter import ttk
from pymongo import MongoClient

def get_indexes():
    # Connect to the MongoDB database
    client = MongoClient('mongodb://localhost:27017')
    db = client['breast']
    collection = db['clinical_data']

    # Get the indexes of the collection
    indexes = collection.index_information()

    # Clear existing data in the labels
    index_info_label.config(text="")
    
    # Insert index data into the label
    for index_name, index_info in indexes.items():
        index_info_label.config(text=index_info_label.cget("text") + f"{index_name}: {index_info}\n")

# Create a Tkinter window
root = tk.Tk()
root.title("Indexing App")

# Create a label to display index information
index_info_label = tk.Label(root, text="", justify="left", font=("Arial", 12))
index_info_label.pack(pady=10)

# Create a button to get the indexes
indexes_button = tk.Button(root, text="Get Indexes", command=get_indexes)
indexes_button.pack()

# Start the Tkinter event loop
root.mainloop()
